# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
net = cv.dnn.readNetFromTensorflow("graph_opt.pb") ##weights

# %%
inWidth = 368
inHeight = 368
thr = 0.2

# %%
BODY_PARTS = { "Nose": 0, "Neck": 1, "RShoulder": 2, "RElbow": 3, "RWrist": 4,
               "LShoulder": 5, "LElbow": 6, "LWrist": 7, "RHip": 8, "RKnee": 9,
               "RAnkle": 10, "LHip": 11, "LKnee": 12, "LAnkle": 13, "REye": 14,
               "LEye": 15, "REar": 16, "LEar": 17, "Background": 18 }

POSE_PAIRS = [ ["Neck", "RShoulder"], ["Neck", "LShoulder"], ["RShoulder", "RElbow"],
               ["RElbow", "RWrist"], ["LShoulder", "LElbow"], ["LElbow", "LWrist"],
               ["Neck", "RHip"], ["RHip", "RKnee"], ["RKnee", "RAnkle"], ["Neck", "LHip"],
               ["LHip", "LKnee"], ["LKnee", "LAnkle"], ["Neck", "Nose"], ["Nose", "REye"],
               ["REye", "REar"], ["Nose", "LEye"], ["LEye", "LEar"] ]

# %%
img = cv.imread("araki.png")

# %%
plt.imshow(img) ##BGR

# %%
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
def pose_estimation(frame):
    frameWidth = frame.shape[1]
    frameHeight = frame.shape[0]
    net.setInput(cv.dnn.blobFromImage(frame, 1.0, (inWidth, inHeight), (127.5, 127.5, 127.5), swapRB=True, crop=False))
    out = net.forward()
    out = out[:, :19, :, :]
    
    assert(len(BODY_PARTS) == out.shape[1])
    
    points = []
    
    for i in range(len(BODY_PARTS)):
        heatMap = out[0, i, :, :]
        _, conf, _, point = cv.minMaxLoc(heatMap)
        if conf > thr:
            x = (frameWidth * point[0]) / out.shape[3]
            y = (frameHeight * point[1]) / out.shape[2]
            points.append((int(x), int(y)))
        else:
            points.append(None)  # Append None if the body part is not detected
        
    for pair in POSE_PAIRS:
        partFrom = pair[0]
        partTo = pair[1]
        idFrom = BODY_PARTS[partFrom]
        idTo = BODY_PARTS[partTo]

        if points[idFrom] is not None and points[idTo] is not None:
            cv.line(frame, points[idFrom], points[idTo], (0,255,0), 3)
            cv.ellipse(frame, points[idFrom], (3,3), 0, 0, 360, (0, 0,255), cv.FILLED)
            cv.ellipse(frame, points[idTo], (3,3), 0, 0, 360, (0, 0,255), cv.FILLED)

            
    t, _ = net.getPerfProfile()
    freq = cv.getTickFrequency() / 1000
    cv.putText(frame, '%.2fms' % (t/freq), (10,20), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0))
    return frame

# %%
estimated_img = pose_estimation(img)

# %%
plt.imshow(cv.cvtColor(estimated_img, cv.COLOR_BGR2RGB))

# %%
boltimg = cv.imread("bolt.png")

# %%
estimated_bolt = pose_estimation(boltimg)

# %%
plt.imshow(cv.cvtColor(estimated_bolt, cv.COLOR_BGR2RGB))

# %%
fleximg = cv.imread("flexing.png")

# %%
estimated_flex = pose_estimation(fleximg)

# %%
plt.imshow(cv.cvtColor(estimated_flex, cv.COLOR_BGR2RGB))

# %%
walkimg = cv.imread("walking.png")

# %%
estimated_walk = pose_estimation(walkimg)
plt.imshow(cv.cvtColor(estimated_walk, cv.COLOR_BGR2RGB))

# %%
###ON WEBCAM
import time
from IPython.display import display, Image
from PIL import Image
import IPython.display

# %%
# Initialize the video capture object
cap = cv.VideoCapture(0)

# Create a display object
d = IPython.display.display("", display_id=1)

try:
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Process the frame with your function
        processed_frame = pose_estimation(frame)

        # Convert the processed frame to JPEG to display in notebook
        _, jpeg_frame = cv2.imencode('.jpg', processed_frame)
        # Create a binary stream to display the image
        f = BytesIO(jpeg_frame)
        
        # Update the display object with the new image
        d.update(Image(data=f.getvalue()))
        
except KeyboardInterrupt:
    print("Stream stopped.")
    cap.release()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 5
#       2 cap = cv.VideoCapture(0)
#       4 # Create a display object
# ----> 5 d = display.display("", display_id=1)
#       7 try:
#       8     while True:
#
# AttributeError: 'function' object has no attribute 'display'
